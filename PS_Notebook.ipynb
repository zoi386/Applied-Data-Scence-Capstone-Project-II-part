# %% [markdown]
# <h1 align = center><font size = 6>APPLIED DATA SCIENCE CAPSTONE PROJECT</font></h1>
# <h3 align = center>(WEEK 1)</h3>

# %% [markdown]
# <h1 align = center>Record of Protected Structures</h1>
# <h2 align = center>Galway County Ireland</h2>

# %% [markdown]
# Data:
# [Published by: Galway County Council](https://data.gov.ie/organization/galway-county-council)
# [Licensed under: Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/)

# %% [markdown]
# ### Introduction
# A protected structure is a structure that the Planning Authority considers to be of special interest from an architectural, historical, archaeological, artistic, cultural, scientific, social or technical point of view. The Planning Authority in its Record of Protected Structures (RPS) includes details of protected structures.A Record of Protected Structures is the record included in a Development Plan, correct at the time of publication. It may be amended by the addition or deletion of entries independently of the Development Plan review process.[source](https://data.gov.ie/dataset/record-of-protected-structures1/resource/de1217cb-5c97-434c-8b05-2114967f642c)

# %% [markdown]
# As it was clearly stated in first paragraph **'Protected structures' are considered to be of special interest** for local goverment and comunity. They have architectural, historical, archeological, artistic, cultural, scientific, social or technical value. These structures in futher text I will call *Cultural heritages*.
# According to [WIKIPEDIA](https://en.wikipedia.org/wiki/Cultural_heritage)  '*Cultural heritage* is the legacy of physical artifacts and intangible attributes of a group or society that is inherited from past generations. Not all legacies of past generations are "heritage", rather heritage is a product of selection by society.'

# %% [markdown]
#  such these Structeres does not just represent rich history and cultural achievements of one nation, group of people or single person, they also inform us about lot of aspects of life from one time, interconnectivity, influence from other nations, struggle one been through. They are keepers of one nation past and history but also enrichment for others.
# In todays societies in time of globalisation, will of one to get know better others is highly valuated. These needs 'to get know and see others',  that are common to all human beings, are primarly satisfied through traveling. **Tourism** is highly appreciated brunch of industry of any country. It brings ravenue but is also beneficial for other industries such as agriculture, small local retail shops, hotels, restaurants museums and other so called tertiary activities.
# It has its bad sides as well, such as overcrowding, waste and noise and it should be addressed properly by responible such as Tourist agencies and domestic governments in order to minimase these negative impacts on local comunities as well as tourists.

# %% [markdown]
# **Ireland** is beautiful green island in the North Atlantic Ocean. It is divided on Republic of Ireland and Northern Ireland which is part of United Kingdom. It is noted for a rich cultural heritage and tradition that is mainly linked to Gaelic language. Ireland is home for 6.4 million people. The island is considered 20-th largest in the world and encompasses 84.421 squared kilometres.
#
# - It is home to numerous castles,
# - Irish people speak English but also Irish which is Gaelic language,
# - St. Patrick is worldwide known Irish saint,
# - Shamrock ☘ and leprechauns are integral and well known part of Irish tradition,
# - Guinness beer best known Irish beer in world,
# - It has oldest known pub 900 years old,
# - Ireland has been inhabited approximately 7000 years,
# are some of interesting facts about Ireland. [source](https://nationfacts.net/ireland-facts/)

# %% [markdown]
# ### Problem
# Apart from well known and worldwide recognized cultural, natural and historical treasuries of Ireland, that bring every year a numerous tourists from around the world, there is a question how much of these are still hidden, or properly represented and offered as tourist attractions.
# In this notebook I will try to give an answer to this question for Galway County.
# I will go through Record of Protected Structurs in Galway County Ireland in order to see how much of them are still in use and their impact on local toursm.

# %% [markdown]
# ### Data acquisition and preparing

# %% [markdown]
# Data that will be used in this project are acquired from [Ireland's open data portal](https://data.gov.ie/). It holds more than 10000 dataset's divided between different sectors.
#     Data set used in this project contain information  about protected structures in Galway County provided by Galway Count Council. Information such as name and type of structure, address, geocordinates, date and identification number, current use, description, appraisal are ready to use.
#     In order to extract and provide answer on actual treatment and inclusion in today tourist prospects of Galaway county they need to be slightly cleaned, and prepared for further use.
#     This means that some columns for this project was not be needed some have to be combined with different sources such as Foursquare app.
#     Complete dataset can be find [here](https://data.gov.ie/dataset/record-of-protected-structures1)

# %% [markdown]
# Let's import some basic libraries and dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Record_of_Protected_Structures.csv')
df.head()
# Out:
#              X            Y     Administrative_Authority_ID  \
# 0  539063.3926  711930.8730  2ae19629-14a5-13a3-e055-000000
# 1  569366.6408  750662.4044  2ae19629-14a5-13a3-e055-000000
# 2  535294.1035  737855.7327  2ae19629-14a5-13a3-e055-000000
# 3  562237.8312  716670.4828  2ae19629-14a5-13a3-e055-000000
# 4  562008.2403  716620.0023  2ae19629-14a5-13a3-e055-000000
#
#   Adinistrative_Authority  Registration_No      Building_Name  \
# 0    Galway County Counci             1010   Thatched Cottage
# 1    Galway County Counci             1006  Windfield House.
# 2    Galway County Counci              101        Cregg Mills
# 3    Galway County Counci             1257      O'Dea's Hotel
# 4    Galway County Counci             1279         L O' Brien
#
#                            Address         County  Eircode  \
# 0   Ballycleary Kinvara Co. Galway  County Galway      NaN
# 1  Newbridge Ballinasloe Co Galway  County Galway      NaN
# 2               Corrandulla GALWAY  County Galway      NaN
# 3     Bride Street Loughrea Galway  County Galway      NaN
# 4      Main Street Loughrea Galway  County Galway      NaN
#
#         Building_Type                                        Description  \
# 0  Thatched structure   Detached 4 bay , single storey thatched cottage.
# 1               House  Detached 3 bay, single storey over basement ho...
# 2          Mill house  DECLARATION Five-bay four-storey mill building...
# 3               Hotel  DECLARATION 11/6/2014  Late 18th century 7 bay...
# 4               House      Large 5 bay 3 storey late 18th century  house
#
#                                            Appraisal Current_Use  NIAH_Number  \
# 0      traditional roof,and  traditional setting.       dwelling   30411304.0
# 1  House which retains original features in inter...         NaN   30404602.0
# 2  DECLARATION Although devoid of machinery the b...    dwelling   30406909.0
# 3  DECLARATION 11/6/2014  The building is of regi...       hotel   30337018.0
# 4                                                NaN         NaN          0.0
#
#   RMP_Number         Date_Registered   Latitude  Longitude  \
# 0          0  1970/01/01 00:00:00+00  53.154390   -8.91107
# 1          0  1970/01/01 00:00:00+00  53.505061   -8.46177
# 2      69024  2002/11/18 00:00:00+00  53.386900   -8.97269
# 3          0  2005/10/25 00:00:00+00  53.199130   -8.56517
# 4          0  2005/10/26 00:00:00+00  53.198660   -8.56860
#
#                                GlobalID  OBJECTID
# 0  65eb6cc0-2bd1-4a6c-81ca-5294d8733ae4      3031
# 1  7ba09b89-2c37-4c4e-b86b-91e882cd7847      3032
# 2  47b9053e-59cc-4ba9-a4f0-61274256f48d      3033
# 3  f66a247a-ff42-4211-b3f4-5f83b4a8ffad      3034
# 4  11270e3c-4aca-4e78-bca1-0a67bb85f0fe      3035

# %%
#Info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1514 entries, 0 to 1513
# Data columns (total 20 columns):
# X                              1514 non-null float64
# Y                              1514 non-null float64
# Administrative_Authority_ID    1514 non-null object
# Adinistrative_Authority        1514 non-null object
# Registration_No                1514 non-null int64
# Building_Name                  1148 non-null object
# Address                        1511 non-null object
# County                         1513 non-null object
# Eircode                        0 non-null float64
# Building_Type                  1513 non-null object
# Description                    1514 non-null object
# Appraisal                      1380 non-null object
# Current_Use                    119 non-null object
# NIAH_Number                    1483 non-null float64
# RMP_Number                     681 non-null object
# Date_Registered                1514 non-null object
# Latitude                       1514 non-null float64
# Longitude                      1514 non-null float64
# GlobalID                       1514 non-null object
# OBJECTID                       1514 non-null int64
# dtypes: float64(6), int64(2), object(12)
# memory usage: 236.6+ KB

# %% [markdown]
# There is 1514 rows and 20 columns. Building name, Appraisal, Curent Use, RMP number miss data, although for Current_Use column we can assume that respresents data about structures that are currently in use while rest is not.

# %% [markdown]
# ## Methodology and Analysis

# %% [markdown]
# The main idea behind this project is to compare data from two differente sources. One of them is dataset accured from Record of protected structures and the second one will be accured from Foursquare. Foursquare is worldwide recognized location platform that holds information about venues around the world. After visiting venues travelers leave information such as pictures, opinions, likes and dislikes or anything else they finde informativ for other users. The both sets should be cleand and prepared for further use aka comparison. In the first step the dataset about Protected structures should be cleand and graphicly represented in order to make a clear picture about all registrated structures. In the second step data for given geocordinates that represent Galway County will be pulled out from Foursquare website prepared for further use - represented as dataframe, and than based on common addresse or geocoordinates comparison will be made.

# %% [markdown]
# Let's clean data set and drop columns that we don't need in further examination.

# %%
df.columns
# Out:
# Index(['X', 'Y', 'Administrative_Authority_ID', 'Adinistrative_Authority',
#        'Registration_No', 'Building_Name', 'Address', 'County', 'Eircode',
#        'Building_Type', 'Description', 'Appraisal', 'Current_Use',
#        'NIAH_Number', 'RMP_Number', 'Date_Registered', 'Latitude', 'Longitude',
#        'GlobalID', 'OBJECTID'],
#       dtype='object')

# %%
df.drop(columns = ['X', 'Y', 'Administrative_Authority_ID', 'Adinistrative_Authority', 'Eircode', 'Registration_No', 'NIAH_Number', 'RMP_Number', 'GlobalID'], axis = 1, inplace = True)
df.head()
# Out:
#        Building_Name                          Address         County  \
# 0   Thatched Cottage   Ballycleary Kinvara Co. Galway  County Galway
# 1  Windfield House.   Newbridge Ballinasloe Co Galway  County Galway
# 2        Cregg Mills               Corrandulla GALWAY  County Galway
# 3      O'Dea's Hotel     Bride Street Loughrea Galway  County Galway
# 4         L O' Brien      Main Street Loughrea Galway  County Galway
#
#         Building_Type                                        Description  \
# 0  Thatched structure   Detached 4 bay , single storey thatched cottage.
# 1               House  Detached 3 bay, single storey over basement ho...
# 2          Mill house  DECLARATION Five-bay four-storey mill building...
# 3               Hotel  DECLARATION 11/6/2014  Late 18th century 7 bay...
# 4               House      Large 5 bay 3 storey late 18th century  house
#
#                                            Appraisal Current_Use  \
# 0      traditional roof,and  traditional setting.       dwelling
# 1  House which retains original features in inter...         NaN
# 2  DECLARATION Although devoid of machinery the b...    dwelling
# 3  DECLARATION 11/6/2014  The building is of regi...       hotel
# 4                                                NaN         NaN
#
#           Date_Registered   Latitude  Longitude  OBJECTID
# 0  1970/01/01 00:00:00+00  53.154390   -8.91107      3031
# 1  1970/01/01 00:00:00+00  53.505061   -8.46177      3032
# 2  2002/11/18 00:00:00+00  53.386900   -8.97269      3033
# 3  2005/10/25 00:00:00+00  53.199130   -8.56517      3034
# 4  2005/10/26 00:00:00+00  53.198660   -8.56860      3035

# %%
df['Building_Type'].value_counts().head(10)
# Out:
# House                 373
# Church                160
# Bridge                152
# Thatched structure    152
# School                 40
# Monument               34
# Railway bridge         33
# Unknown                31
# Waterpump              31
# Gate lodge             31
# Name: Building_Type, dtype: int64

# %% [markdown]
#  As it can be seen from previous there is a lot of different kind of protected buildings. Let's enlist those currently in use.

# %%
df['Current_Use'].value_counts().head(10)
# Out:
# dwelling            20
# house                9
# place of worship     8
# church               7
# hotel                6
# ruin                 6
# derelict             4
# vacant               3
# House and Shop       2
# unused               2
# Name: Current_Use, dtype: int64

# %% [markdown]
# It's already clearly visible that amoung enlisted protected structures a few are currently in use 119 from 1514 to be more precise, and most of those that have been used are dwellings and houses although there are a lot of different building types that can be used as tourist attractions. 26 Castles, 26 shops, 36 monuments, 12 financial institutions to name a few although the complete list is remarkable.

# %%
df_count = df.groupby('Building_Type').count()
df_count.head(50)
# Out:
#                       Building_Name  Address  County  Description  Appraisal  \
# Building_Type
# Abbey                             2        2       2            2          2
# Arch                              4        4       4            4          2
# Bank/financial insti             11       12      12           12         10
# Barn                              0        1       1            1          1
# Barracks                          3        5       5            5          4
# Bell tower                        0        1       1            1          1
# Bishop's Palace                   1        1       1            1          1
# Boathouse                         1        1       1            1          1
# Brewery                           1        1       1            1          1
# Bridge                          109      152     152          152        149
# Building misc                     4        4       4            4          2
# Canal (section of)                4        5       5            5          5
# Canal bridge                      1        1       1            1          1
# Castle                           26       26      26           26         26
# Cathedral                         5        5       5            5          4
# Cemetery                          2        2       2            2          0
# Chapel                            3        3       3            3          3
# Church                          158      159     160          160        158
# Coastguard cottage                3        3       3            3          3
# Coastguard station                7        7       7            7          7
# College (theological              1        1       1            1          1
# Convent/nunnery                  15       16      16           16         15
# Country house                     6        6       6            6          6
# Court house                      10       10      10           10          8
# Crane (fixed)                     1        1       1            1          1
# Dam/reservoir (mill)              1        1       1            1          1
# Dispensary                        0        1       1            1          1
# Factory                           1        1       1            1          1
# Farm house                        1        1       1            1          1
# Farmyard complex                  6        7       7            7          7
# Folly                             3        3       3            3          3
# Forge                             1        3       3            3          3
# Fort                              1        1       1            1          1
# Game keepers house                0        1       1            1          1
# Garden                            2        2       2            2          2
# Gasworks                          1        1       1            1          1
# Gate lodge                       27       31      31           31         31
# Gates/railings                   25       27      27           27         27
# Graveyard                        11       12      12           12         11
# Grotto/shrine/orator              0        2       2            2          2
# Hall                              1        1       1            1          1
# Hall/lodge                        1        1       1            1          1
# Harbour/dock                      3        3       3            3          3
# Holy well                         1        1       1            1          1
# Hospital                          1        1       1            1          1
# Hotel                             8        8       8            8          7
# House                           325      371     373          373        307
# Icehouse                          4        4       4            4          4
# Industrial school                 2        2       2            2          2
# Kiln                              3        6       6            6          6
#
#                       Current_Use  Date_Registered  Latitude  Longitude  \
# Building_Type
# Abbey                           0                2         2          2
# Arch                            0                4         4          4
# Bank/financial insti            2               12        12         12
# Barn                            0                1         1          1
# Barracks                        0                5         5          5
# Bell tower                      0                1         1          1
# Bishop's Palace                 0                1         1          1
# Boathouse                       0                1         1          1
# Brewery                         0                1         1          1
# Bridge                          0              152       152        152
# Building misc                   1                4         4          4
# Canal (section of)              0                5         5          5
# Canal bridge                    0                1         1          1
# Castle                          2               26        26         26
# Cathedral                       0                5         5          5
# Cemetery                        0                2         2          2
# Chapel                          0                3         3          3
# Church                         21              160       160        160
# Coastguard cottage              0                3         3          3
# Coastguard station              1                7         7          7
# College (theological            0                1         1          1
# Convent/nunnery                 2               16        16         16
# Country house                   3                6         6          6
# Court house                     2               10        10         10
# Crane (fixed)                   0                1         1          1
# Dam/reservoir (mill)            0                1         1          1
# Dispensary                      0                1         1          1
# Factory                         1                1         1          1
# Farm house                      0                1         1          1
# Farmyard complex                3                7         7          7
# Folly                           1                3         3          3
# Forge                           0                3         3          3
# Fort                            0                1         1          1
# Game keepers house              0                1         1          1
# Garden                          0                2         2          2
# Gasworks                        1                1         1          1
# Gate lodge                      1               31        31         31
# Gates/railings                  3               27        27         27
# Graveyard                       2               12        12         12
# Grotto/shrine/orator            0                2         2          2
# Hall                            0                1         1          1
# Hall/lodge                      1                1         1          1
# Harbour/dock                    1                3         3          3
# Holy well                       0                1         1          1
# Hospital                        0                1         1          1
# Hotel                           4                8         8          8
# House                          31              373       373        373
# Icehouse                        0                4         4          4
# Industrial school               1                2         2          2
# Kiln                            0                6         6          6
#
#                       OBJECTID
# Building_Type
# Abbey                        2
# Arch                         4
# Bank/financial insti        12
# Barn                         1
# Barracks                     5
# Bell tower                   1
# Bishop's Palace              1
# Boathouse                    1
# Brewery                      1
# Bridge                     152
# Building misc                4
# Canal (section of)           5
# Canal bridge                 1
# Castle                      26
# Cathedral                    5
# Cemetery                     2
# Chapel                       3
# Church                     160
# Coastguard cottage           3
# Coastguard station           7
# College (theological         1
# Convent/nunnery             16
# Country house                6
# Court house                 10
# Crane (fixed)                1
# Dam/reservoir (mill)         1
# Dispensary                   1
# Factory                      1
# Farm house                   1
# Farmyard complex             7
# Folly                        3
# Forge                        3
# Fort                         1
# Game keepers house           1
# Garden                       2
# Gasworks                     1
# Gate lodge                  31
# Gates/railings              27
# Graveyard                   12
# Grotto/shrine/orator         2
# Hall                         1
# Hall/lodge                   1
# Harbour/dock                 3
# Holy well                    1
# Hospital                     1
# Hotel                        8
# House                      373
# Icehouse                     4
# Industrial school            2
# Kiln                         6

# %%
df_count = df_count.loc[:, ['Current_Use', 'OBJECTID']].sort_values(by = 'OBJECTID', ascending = False)
print(df_count.head(20))
print(df_count.shape)
# Out:
#                       Current_Use  OBJECTID
# Building_Type
# House                          31       373
# Church                         21       160
# Bridge                          0       152
# Thatched structure              7       152
# School                          2        40
# Monument                        1        34
# Railway bridge                  0        33
# Waterpump                       0        31
# Unknown                         1        31
# Gate lodge                      1        31
# Gates/railings                  3        27
# Castle                          2        26
# Shop                            2        26
# Post Box                        1        23
# Railway station                 3        23
# Quay/wharf                      1        22
# Mill house                      4        21
# Convent/nunnery                 2        16
# Graveyard                       2        12
# Bank/financial insti            2        12
# (108, 2)

# %% [markdown]
# There is 108 different Building Type in dataset. Since OBJECTID uniformly designes every protected unit regardless missing data in other columns, based on it can be seen currently used number of those enlisted in register.

# %%
df_count = df_count[:20] #first 20

# %%
x = np.arange(len(df_count.index))
width = .40
fig, ax = plt.subplots(figsize = (20, 6))
col1 = ax.bar(x - width / 2, df_count.OBJECTID, width, label = 'ObjectId')
col2 = ax.bar(x + width / 2, df_count.Current_Use, width, label = 'Current Use')
ax.set_title('Relation betwen enlisted structures and currently used structures')
ax.set_ylabel('Number of enlisted structires')
ax.set_xticks(x)
ax.set_xticklabels(df_count.index)
ax.legend()

plt.setp(ax.get_xticklabels(), rotation = 30, ha = 'right', rotation_mode='anchor')

def autolabel(cols):
    for col in cols:
        height = col.get_height()
        ax.annotate('{}'.format(height),
                    xy=(col.get_x() + col.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(col1)
autolabel(col2)

plt.show()

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim
import requests
import json
from pandas.io.json import json_normalize
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda/win-64::ca-certificates-2019.1.23-0, anaconda/win-64::openssl-1.1.1b-he774522_1
#   - anaconda/win-64::ca-certificates-2019.1.23-0, defaults/win-64::openssl-1.1.1b-he774522_1
#   - anaconda/win-64::openssl-1.1.1b-he774522_1, defaults/win-64::ca-certificates-2019.1.23-0
#   - defaults/win-64::ca-certificates-2019.1.23-0, defaults/win-64::openssl-1.1.1b-he774522_1done
#
# # All requested packages already installed.
#
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda/win-64::ca-certificates-2019.1.23-0, anaconda/win-64::openssl-1.1.1b-he774522_1
#   - anaconda/win-64::ca-certificates-2019.1.23-0, defaults/win-64::openssl-1.1.1b-he774522_1
#   - anaconda/win-64::openssl-1.1.1b-he774522_1, defaults/win-64::ca-certificates-2019.1.23-0
#   - defaults/win-64::ca-certificates-2019.1.23-0, defaults/win-64::openssl-1.1.1b-he774522_1done
#
# # All requested packages already installed.

# %% [markdown]
# Now I will get GeoCoordinates for Galway County, Ireland.

# %%
address = 'Galway, Ireland'
geolocator = Nominatim(user_agent = 'galway_co')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Geographical coordinates of Galway County, Ireland are: latitude {} and longitude {} '.format(latitude, longitude))
# Out:
# Geographical coordinates of Galway County, Ireland are: latitude 53.2744122 and longitude -9.0490632

# %% [markdown]
# Galaway County, Ireland map is as follows:

# %%
galway_map = folium.Map(location = [latitude, longitude], zoom_start = 12)
galway_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Galway County so far has 1514 registrated cultural heritages from which only 119 are currently in use. Let's  map them!

# %%
df_inuse = df[df['Current_Use'].notna()].reset_index(drop = True)
df_inuse.head()
# Out:
#       Building_Name                                Address         County  \
# 0  Thatched Cottage         Ballycleary Kinvara Co. Galway  County Galway
# 1       Cregg Mills                     Corrandulla GALWAY  County Galway
# 2     O'Dea's Hotel           Bride Street Loughrea Galway  County Galway
# 3             House           Bride Street Loughrea Galway  County Galway
# 4               AIB  Society Street Ballinasloe Co. Galway  County Galway
#
#           Building_Type                                        Description  \
# 0    Thatched structure   Detached 4 bay , single storey thatched cottage.
# 1            Mill house  DECLARATION Five-bay four-storey mill building...
# 2                 Hotel  DECLARATION 11/6/2014  Late 18th century 7 bay...
# 3                 House  DECLARATION 11/11/2016 Detached 3 bay, 2 store...
# 4  Bank/financial insti  DECLARATION 5/2/2015 Terraced five-bay three-s...
#
#                                            Appraisal Current_Use  \
# 0      traditional roof,and  traditional setting.       dwelling
# 1  DECLARATION Although devoid of machinery the b...    dwelling
# 2  DECLARATION 11/6/2014  The building is of regi...       hotel
# 3  DECLARATION 11/11/2016 This building presents ...    dwelling
# 4  DECLARATION 5/2/2015 Regional value because of...        Bank
#
#           Date_Registered  Latitude  Longitude  OBJECTID
# 0  1970/01/01 00:00:00+00  53.15439   -8.91107      3031
# 1  2002/11/18 00:00:00+00  53.38690   -8.97269      3033
# 2  2005/10/25 00:00:00+00  53.19913   -8.56517      3034
# 3  2005/10/26 00:00:00+00  53.19968   -8.56263      3036
# 4  2002/11/18 00:00:00+00  53.33018   -8.22169      3037

# %%
df_inuse.shape
# Out:
# (119, 11)

# %%
galway_map = folium.Map(location = [latitude, longitude], zoom_start = 9)

#markdown heritages currently in use 

for lat, lng, building_name in zip(df_inuse['Latitude'], df_inuse['Longitude'], df_inuse['Building_Name']):
    label = building_name
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'green',
        fill = True,
        fill_color = 'grey',
        fill_opacity = .6,
        parse_html = False).add_to(galway_map)
galway_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
galway_map_all = folium.Map(location = [latitude, longitude], zoom_start = 9)

#markdown all registrated heritages:

for lat, lng, building_name in zip(df['Latitude'], df['Longitude'], df['Building_Name']):
    label = building_name
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'Purple',
        fill = True,
        fill_color = 'grey',
        fill_opacity = .6,
        parse_html = False).add_to(galway_map_all)
galway_map_all
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# After mapping data from first dataset - Register of Protected Structures, lets map venues in this County from the other source - Foursquare platform.

# %%
client_id = '0U4M3ZHKDLOWLMYZNTHUPMWF0HUMVGG5VADKKNRULDMEGW4M' 
client_secret = '3A1EPFMKK1VQ1QRTT455CMJ2EK3ZE0WQ23M3RK4AQSKYTHSX' 
version = '20201201'
limit = 1500
radius = 6000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(client_id, client_secret, latitude, longitude, version, radius, limit)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=0U4M3ZHKDLOWLMYZNTHUPMWF0HUMVGG5VADKKNRULDMEGW4M&client_secret=3A1EPFMKK1VQ1QRTT455CMJ2EK3ZE0WQ23M3RK4AQSKYTHSX&ll=53.2744122,-9.0490632&v=20201201&radius=6000&limit=1500'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fd3b92a1d98ae664e1a1944'},
#  'response': {'venues': [{'id': '522322d0498ee3e39d979b57',
#     'name': 'The Browne Doorway',
#     'location': {'address': 'Eyre Sq',
#      'lat': 53.27477630954029,
#      'lng': -9.049725968225495,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27477630954029,
#        'lng': -9.049725968225495}],
#      'distance': 59,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d166941735',
#       'name': 'Sculpture Garden',
#       'pluralName': 'Sculpture Gardens',
#       'shortName': 'Sculpture',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b6ef741f964a520a9d32ce3',
#     'name': 'Eyre Square',
#     'location': {'address': 'An Fhaiche Mhór',
#      'lat': 53.27449738551782,
#      'lng': -9.049172401428223,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27449738551782,
#        'lng': -9.049172401428223}],
#      'distance': 11,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['An Fhaiche Mhór',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d164941735',
#       'name': 'Plaza',
#       'pluralName': 'Plazas',
#       'shortName': 'Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '56178f87498e3bd23df18f8c',
#     'name': 'Esquires Coffee',
#     'location': {'address': '11 Eyre Square',
#      'lat': 53.274371,
#      'lng': -9.048041,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274371,
#        'lng': -9.048041}],
#      'distance': 68,
#      'cc': 'IE',
#      'neighborhood': 'Eyre Square',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['11 Eyre Square', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b641d83f964a520c49f2ae3',
#     'name': 'Meyrick Hotel',
#     'location': {'address': 'Eyre Sq',
#      'lat': 53.274187651577485,
#      'lng': -9.048374137137621,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274187651577485,
#        'lng': -9.048374137137621}],
#      'distance': 52,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '558a8a96498e2fb39e16521f',
#     'name': "McGettigan's",
#     'location': {'address': '9-11 Prospect Hill',
#      'lat': 53.27537801076868,
#      'lng': -9.048960186408964,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27537801076868,
#        'lng': -9.048960186408964}],
#      'distance': 107,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['9-11 Prospect Hill',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'shortName': 'Gastropub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4be1aeb88dd062b5597b3e3c',
#     'name': 'Skeffington Arms Hotel',
#     'location': {'address': 'Eyre Sq',
#      'lat': 53.27422769415862,
#      'lng': -9.049687537422159,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27422769415862,
#        'lng': -9.049687537422159}],
#      'distance': 46,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4be54bfc2468c92821daff42',
#     'name': 'Corrib Shopping Centre',
#     'location': {'address': 'Eyre St',
#      'lat': 53.27542777992054,
#      'lng': -9.050416875798234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27542777992054,
#        'lng': -9.050416875798234}],
#      'distance': 144,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre St', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1fd941735',
#       'name': 'Shopping Mall',
#       'pluralName': 'Shopping Malls',
#       'shortName': 'Mall',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5b686bf7e96d0c002ca3d69e',
#     'name': 'Lynchs Castle',
#     'location': {'lat': 53.27329,
#      'lng': -9.052086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27329,
#        'lng': -9.052086}],
#      'distance': 236,
#      'cc': 'IE',
#      'neighborhood': 'St. Nicholas',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '50aaa49e4b90af0d42d5de11',
#       'name': 'Castle',
#       'pluralName': 'Castles',
#       'shortName': 'Castle',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b983585f964a520603435e3',
#     'name': 'The Skeff',
#     'location': {'address': 'Eyre Sq',
#      'lat': 53.274120143583,
#      'lng': -9.049978118517991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274120143583,
#        'lng': -9.049978118517991}],
#      'distance': 69,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4bd590b95631c9b6503da430',
#     'name': 'An Post',
#     'location': {'lat': 53.27442581304661,
#      'lng': -9.048861375034361,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27442581304661,
#        'lng': -9.048861375034361}],
#      'distance': 13,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d172941735',
#       'name': 'Post Office',
#       'pluralName': 'Post Offices',
#       'shortName': 'Post Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '53495199498e14b6d3ab10b5',
#     'name': 'The Dough Bros',
#     'location': {'address': 'Middle St',
#      'lat': 53.27268249426422,
#      'lng': -9.051697991661433,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27268249426422,
#        'lng': -9.051697991661433}],
#      'distance': 260,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Middle St', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '58c7f6b77b88a73f653685c2',
#     'name': 'AXA Insurance',
#     'location': {'address': 'Woodquay Court',
#      'lat': 53.27434982530317,
#      'lng': -9.048893451690674,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27434982530317,
#        'lng': -9.048893451690674}],
#      'distance': 13,
#      'postalCode': 'H91 XW5A',
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Woodquay Court', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1f1',
#       'name': 'Insurance Office',
#       'pluralName': 'Insurance Offices',
#       'shortName': 'Insurance Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '590dd9a728374e10e4241aee',
#     'name': 'Starbucks',
#     'location': {'address': 'Eyre Square Shopping Centre',
#      'lat': 53.27363112900194,
#      'lng': -9.049349509145403,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27363112900194,
#        'lng': -9.049349509145403}],
#      'distance': 89,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Square Shopping Centre',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b086877f964a520340b23e3',
#     'name': "O'Connell's",
#     'location': {'address': '8 Eyre Sq',
#      'lat': 53.27449014278099,
#      'lng': -9.048592227434257,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27449014278099,
#        'lng': -9.048592227434257}],
#      'distance': 32,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['8 Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4dc97374e4cd1818d5b89db3',
#     'name': 'Café Express',
#     'location': {'address': '32 Eyre Sq',
#      'lat': 53.274465307253635,
#      'lng': -9.05047059059143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274465307253635,
#        'lng': -9.05047059059143}],
#      'distance': 93,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['32 Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5b03061d780eee002cebfbd1',
#     'name': 'Burkes Bus Galway',
#     'location': {'lat': 53.274375,
#      'lng': -9.048323,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274375,
#        'lng': -9.048323}],
#      'distance': 49,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1fe931735',
#       'name': 'Bus Station',
#       'pluralName': 'Bus Stations',
#       'shortName': 'Bus Station',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5706b844498e54311369e776',
#     'name': 'Dealz',
#     'location': {'address': 'Hibernian House, Eyre Square',
#      'crossStreet': 'Eyre Sq',
#      'lat': 53.2753283,
#      'lng': -9.0499395,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.2753283,
#        'lng': -9.0499395}],
#      'distance': 117,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Hibernian House, Eyre Square (Eyre Sq)',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#       'name': 'Discount Store',
#       'pluralName': 'Discount Stores',
#       'shortName': 'Discount Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4dd7a53fe4cd37c893b0090f',
#     'name': 'Paddys Bar',
#     'location': {'lat': 53.27608463280089,
#      'lng': -9.048689296959354,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27608463280089,
#        'lng': -9.048689296959354}],
#      'distance': 187,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5d78f103863de600077321ac',
#     'name': 'Free Walking Tour Galway',
#     'location': {'lat': 53.27422,
#      'lng': -9.049879,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27422,
#        'lng': -9.049879}],
#      'distance': 58,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '56aa371be4b08b9a8d573520',
#       'name': 'Tour Provider',
#       'pluralName': 'Tour Providers',
#       'shortName': 'Tour Provider',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5e42c8f5b8c0660008ac7fea',
#     'name': 'Remax',
#     'location': {'lat': 53.274632,
#      'lng': -9.048458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274632,
#        'lng': -9.048458}],
#      'distance': 47,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '5032885091d4c4b30a586d66',
#       'name': 'Real Estate Office',
#       'pluralName': 'Real Estate Offices',
#       'shortName': 'Real Estate',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5d57e019284dc20008b905af',
#     'name': 'John F Kennedy Monument',
#     'location': {'lat': 53.274512,
#      'lng': -9.048498,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274512,
#        'lng': -9.048498}],
#      'distance': 39,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d12d941735',
#       'name': 'Monument / Landmark',
#       'pluralName': 'Monuments / Landmarks',
#       'shortName': 'Landmark',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4c5841a52308be9accf55a6c',
#     'name': 'Shake',
#     'location': {'address': 'Corbett Court Shopping Centre',
#      'lat': 53.27435503032173,
#      'lng': -9.05060865659262,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27435503032173,
#        'lng': -9.05060865659262}],
#      'distance': 103,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Corbett Court Shopping Centre',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d0941735',
#       'name': 'Dessert Shop',
#       'pluralName': 'Dessert Shops',
#       'shortName': 'Desserts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '598c315fc0cacb28d86a6f7b',
#     'name': 'Caffè Nero',
#     'location': {'address': 'Eyre Square',
#      'lat': 53.27437217373234,
#      'lng': -9.04980364698428,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27437217373234,
#        'lng': -9.04980364698428}],
#      'distance': 49,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Square', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4c5038f3371520a1adf1f2c0',
#     'name': 'Gala Express',
#     'location': {'address': '6 Prospect Hill',
#      'lat': 53.275149,
#      'lng': -9.049146,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.275149,
#        'lng': -9.049146}],
#      'distance': 82,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['6 Prospect Hill',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4e4bd38722713bd908c2ea76',
#     'name': 'Lazlo Jewellers',
#     'location': {'address': '20 William St',
#      'crossStreet': 'Galway City',
#      'lat': 53.274742,
#      'lng': -9.0489384,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274742,
#        'lng': -9.0489384}],
#      'distance': 37,
#      'postalCode': 'H91 F8D9',
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['20 William St (Galway City)',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'shortName': 'Jewelry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5d5d7852a20381000786d723',
#     'name': 'Liam Maoiliosa Statue',
#     'location': {'lat': 53.275094,
#      'lng': -9.049232,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.275094,
#        'lng': -9.049232}],
#      'distance': 76,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d12d941735',
#       'name': 'Monument / Landmark',
#       'pluralName': 'Monuments / Landmarks',
#       'shortName': 'Landmark',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '598652adbd400967fb7a0611',
#     'name': 'DNA',
#     'location': {'lat': 53.273721,
#      'lng': -9.050246,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.273721,
#        'lng': -9.050246}],
#      'distance': 110,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '52012547498e621d68695acc',
#     'name': 'Tropical Medical Bureau',
#     'location': {'lat': 53.274925231933594,
#      'lng': -9.048766136169434,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274925231933594,
#        'lng': -9.048766136169434}],
#      'distance': 60,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d104941735',
#       'name': 'Medical Center',
#       'pluralName': 'Medical Centers',
#       'shortName': 'Medical',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4baeccfaf964a52027d93be3',
#     'name': 'Eyre Square Hotel',
#     'location': {'address': 'Forster St',
#      'lat': 53.274301433399124,
#      'lng': -9.04742766284189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274301433399124,
#        'lng': -9.04742766284189}],
#      'distance': 109,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Forster St', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4e22c8cdd4c0d32590fc3b68',
#     'name': "Ciarán's Accommodation",
#     'location': {'address': '50 Prospect Hill',
#      'lat': 53.274426,
#      'lng': -9.048941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274426,
#        'lng': -9.048941}],
#      'distance': 8,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['50 Prospect Hill',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1f8931735',
#       'name': 'Bed & Breakfast',
#       'pluralName': 'Bed & Breakfasts',
#       'shortName': 'B & B',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/bedandbreakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5c695aa2f709c1002cef8576',
#     'name': 'Merchant Cafè',
#     'location': {'lat': 53.274297,
#      'lng': -9.047625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274297,
#        'lng': -9.047625}],
#      'distance': 96,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5998489e340a58724eba7172',
#     'name': "Darcy's Bar",
#     'location': {'address': '1 Forster Street',
#      'lat': 53.274185,
#      'lng': -9.047693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274185,
#        'lng': -9.047693}],
#      'distance': 94,
#      'postalCode': 'H91 TX67',
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['1 Forster Street',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11d941735',
#       'name': 'Sports Bar',
#       'pluralName': 'Sports Bars',
#       'shortName': 'Sports Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4c9f4f6319e4236a99935789',
#     'name': 'Garveys Inn',
#     'location': {'address': 'Forster St',
#      'crossStreet': 'at Eyre Square',
#      'lat': 53.27427891092319,
#      'lng': -9.04784063418933,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27427891092319,
#        'lng': -9.04784063418933}],
#      'distance': 82,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Forster St (at Eyre Square)',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4bc229a7abf495213715c293',
#     'name': 'An Púcán',
#     'location': {'address': 'Forster St',
#      'lat': 53.27448101403289,
#      'lng': -9.047498251545203,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27448101403289,
#        'lng': -9.047498251545203}],
#      'distance': 104,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Forster St', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4c66ec15e1da1b8d226e9cc3',
#     'name': 'Centra',
#     'location': {'address': 'Forster Street',
#      'lat': 53.27446820647189,
#      'lng': -9.047582004264891,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27446820647189,
#        'lng': -9.047582004264891}],
#      'distance': 98,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Forster Street', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5cad18691fa763002c3b0053',
#     'name': 'Vocho',
#     'location': {'address': '19 Forster St',
#      'lat': 53.2746192827023,
#      'lng': -9.04725730419159,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.2746192827023,
#        'lng': -9.04725730419159}],
#      'distance': 122,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['19 Forster St', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d153941735',
#       'name': 'Burrito Place',
#       'pluralName': 'Burrito Places',
#       'shortName': 'Burritos',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4c335c58ed37a593e2326d03',
#     'name': 'Kennedys',
#     'location': {'lat': 53.27510133582143,
#      'lng': -9.049270734823935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27510133582143,
#        'lng': -9.049270734823935}],
#      'distance': 77,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b9799c1f964a520f50a35e3',
#     'name': 'Ulster Bank',
#     'location': {'address': 'Eyre Square',
#      'lat': 53.274633740476844,
#      'lng': -9.050177768889561,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274633740476844,
#        'lng': -9.050177768889561}],
#      'distance': 78,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Square', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b807590f964a5205a7430e3',
#     'name': 'Galway Bakery Company',
#     'location': {'address': 'Williamsgate St',
#      'lat': 53.27421653020562,
#      'lng': -9.050872740634675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27421653020562,
#        'lng': -9.050872740634675}],
#      'distance': 122,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Williamsgate St',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4be58bd9910020a1c613d314',
#     'name': 'Murty Rabbitts',
#     'location': {'address': 'Forster St',
#      'lat': 53.27475120700575,
#      'lng': -9.046890991885535,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27475120700575,
#        'lng': -9.046890991885535}],
#      'distance': 149,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Forster St', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5241540111d2d9b080dd5426',
#     'name': 'The Beauty Lounge',
#     'location': {'address': 'Level 3, Eyre Square Shopping Centre',
#      'crossStreet': 'Eyre Square',
#      'lat': 53.27373123168945,
#      'lng': -9.050250053405762,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27373123168945,
#        'lng': -9.050250053405762}],
#      'distance': 109,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Level 3, Eyre Square Shopping Centre (Eyre Square)',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4f04aa0c2fb6e1c99f3db0b8',
#       'name': 'Nail Salon',
#       'pluralName': 'Nail Salons',
#       'shortName': 'Nail Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/nailsalon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5d8b200d7892ec000852bc4f',
#     'name': 'Wild Atlantic Way Tours',
#     'location': {'lat': 53.273323,
#      'lng': -9.048768,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.273323,
#        'lng': -9.048768}],
#      'distance': 122,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '56aa371be4b08b9a8d573520',
#       'name': 'Tour Provider',
#       'pluralName': 'Tour Providers',
#       'shortName': 'Tour Provider',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b979a0af964a520ff0a35e3',
#     'name': 'Bank of Ireland',
#     'location': {'address': '43 Eyre Square',
#      'lat': 53.27495393009746,
#      'lng': -9.04994570629046,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27495393009746,
#        'lng': -9.04994570629046}],
#      'distance': 84,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['43 Eyre Square', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4bbb212d53649c748fad49fb',
#     'name': 'Mocha Beans',
#     'location': {'address': '7-27 Forster St',
#      'lat': 53.274313328941865,
#      'lng': -9.04763564241538,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274313328941865,
#        'lng': -9.04763564241538}],
#      'distance': 95,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['7-27 Forster St',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5a5d163a065ef50b1ffc9c8d',
#     'name': 'Snap Fitness Galway',
#     'location': {'address': 'Prospect Hill',
#      'lat': 53.27550107993139,
#      'lng': -9.04875749759987,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27550107993139,
#        'lng': -9.04875749759987}],
#      'distance': 122,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Prospect Hill', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4c6ab7ba0e98a5938fac2759',
#     'name': 'Galway City Hostel',
#     'location': {'address': 'Frenchville Ln, Eyre Sq',
#      'lat': 53.27423169964248,
#      'lng': -9.048026884101997,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27423169964248,
#        'lng': -9.048026884101997}],
#      'distance': 71,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Frenchville Ln, Eyre Sq',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '508106eee4b091f169457971',
#     'name': 'Bus Stop 409',
#     'location': {'lat': 53.27447947259556,
#      'lng': -9.04846579858599,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27447947259556,
#        'lng': -9.04846579858599}],
#      'distance': 40,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#       'name': 'Bus Stop',
#       'pluralName': 'Bus Stops',
#       'shortName': 'Bus Stop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4d6135d4618aa090402808e2',
#     'name': 'Charcoal Grill',
#     'location': {'address': '3 Prospect Hill',
#      'lat': 53.27529490895666,
#      'lng': -9.04908437660692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27529490895666,
#        'lng': -9.04908437660692}],
#      'distance': 98,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['3 Prospect Hill',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b6da3f5f964a52084822ce3',
#     'name': "Fibber McGee's",
#     'location': {'address': 'Eyre Sq',
#      'lat': 53.27489878954885,
#      'lng': -9.048968257231381,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27489878954885,
#        'lng': -9.048968257231381}],
#      'distance': 54,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11b941735',
#       'name': 'Pub',
#       'pluralName': 'Pubs',
#       'shortName': 'Pub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4d04d64a30a58cfaf6ffa1e7',
#     'name': 'Logues Shoe Shop',
#     'location': {'lat': 53.274284,
#      'lng': -9.050495,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274284,
#        'lng': -9.050495}],
#      'distance': 96,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d107951735',
#       'name': 'Shoe Store',
#       'pluralName': 'Shoe Stores',
#       'shortName': 'Shoes',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '537fa447498e1b7adfb8bd92',
#     'name': 'Gaslight Bar & Brasserie',
#     'location': {'address': 'Eyre Sq',
#      'lat': 53.27436828613281,
#      'lng': -9.048433303833008,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27436828613281,
#        'lng': -9.048433303833008}],
#      'distance': 42,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4c54adcb06901b8dc8062c4c',
#     'name': 'Richardsons',
#     'location': {'lat': 53.27515888788759,
#      'lng': -9.049128703606673,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27515888788759,
#        'lng': -9.049128703606673}],
#      'distance': 83,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4bcd79e7cc8cd13ac397c2cf',
#     'name': 'AIB',
#     'location': {'address': '18 Eyre Sq',
#      'lat': 53.273821441477274,
#      'lng': -9.048785461133622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.273821441477274,
#        'lng': -9.048785461133622}],
#      'distance': 68,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['18 Eyre Sq', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5195334c498eb1ac8c8122dd',
#     'name': 'Oyster Grill',
#     'location': {'lat': 53.274175,
#      'lng': -9.048334,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274175,
#        'lng': -9.048334}],
#      'distance': 55,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5915ae66a30619669eafb396',
#     'name': 'Budget Car Rental Galway',
#     'location': {'address': '12 Eyre Square, Galway City Centre',
#      'lat': 53.274334433019455,
#      'lng': -9.04792323919711,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274334433019455,
#        'lng': -9.04792323919711}],
#      'distance': 76,
#      'postalCode': 'H91 TW2K',
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['12 Eyre Square, Galway City Centre',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1ef941735',
#       'name': 'Rental Car Location',
#       'pluralName': 'Rental Car Locations',
#       'shortName': 'Rental Car',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/airport_rentalcar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5ccacc46f427de002ce959d0',
#     'name': 'Snoozles Hostel Galway',
#     'location': {'address': 'Galway, Ireland NW1',
#      'lat': 53.274900927986195,
#      'lng': -9.048764705657959,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274900927986195,
#        'lng': -9.048764705657959}],
#      'distance': 57,
#      'postalCode': 'NW1',
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway, Ireland NW1',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4e4538e8d4c065cb6b8e083a',
#     'name': 'Nora Barnacle House Museum',
#     'location': {'address': 'Bowling Green',
#      'lat': 53.27436211968561,
#      'lng': -9.047352739918036,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27436211968561,
#        'lng': -9.047352739918036}],
#      'distance': 113,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Bowling Green', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d190941735',
#       'name': 'History Museum',
#       'pluralName': 'History Museums',
#       'shortName': 'History Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4cca11fab7d9a1437c50fa36',
#     'name': "Coyote's",
#     'location': {'address': 'Foster St',
#      'lat': 53.27280129638932,
#      'lng': -9.052737214365669,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27280129638932,
#        'lng': -9.052737214365669}],
#      'distance': 303,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Foster St', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4dc4325fe4cd169dc62ce88f',
#     'name': 'Oyster Bar',
#     'location': {'address': 'Meyrick Hotel',
#      'lat': 53.273810905409235,
#      'lng': -9.048056602478027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.273810905409235,
#        'lng': -9.048056602478027}],
#      'distance': 94,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Meyrick Hotel', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1d5941735',
#       'name': 'Hotel Bar',
#       'pluralName': 'Hotel Bars',
#       'shortName': 'Hotel Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '59d2822ae2ead1169ec44198',
# ...
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5a0c56958194fc771289349b',
#     'name': 'Regatta Great Outdoors',
#     'location': {'lat': 53.273631,
#      'lng': -9.049347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.273631,
#        'lng': -9.049347}],
#      'distance': 88,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '580b789b38faa26bf0556236',
#     'name': 'Cex',
#     'location': {'lat': 53.274365,
#      'lng': -9.047197,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274365,
#        'lng': -9.047197}],
#      'distance': 124,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d10b951735',
#       'name': 'Video Game Store',
#       'pluralName': 'Video Game Stores',
#       'shortName': 'Video Games',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/videogames_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4b64e332f964a52096d72ae3',
#     'name': 'Club Q',
#     'location': {'address': 'Radisson Hotel',
#      'lat': 53.27436412649219,
#      'lng': -9.050594322728642,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27436412649219,
#        'lng': -9.050594322728642}],
#      'distance': 102,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Radisson Hotel', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4deb8fbcd22da22d4ef04898',
#     'name': 'Kilronan',
#     'location': {'address': 'Inis Mor',
#      'lat': 53.274416681292486,
#      'lng': -9.049002084639937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274416681292486,
#        'lng': -9.049002084639937}],
#      'distance': 4,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Inis Mor', 'Ireland']},
#     'categories': [],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5357f54b498e123098972ef9',
#     'name': 'Citylink Dublin to Galway',
#     'location': {'lat': 53.274006645754305,
#      'lng': -9.048046641500337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274006645754305,
#        'lng': -9.048046641500337}],
#      'distance': 81,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d12b951735',
#       'name': 'Bus Line',
#       'pluralName': 'Bus Lines',
#       'shortName': 'Bus',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '578e55b4498e4401d720edfd',
#     'name': 'LloydsPharmacy',
#     'location': {'lat': 53.27457,
#      'lng': -9.047245,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27457,
#        'lng': -9.047245}],
#      'distance': 122,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4e1425df1fc78d2d5d124990',
#     'name': 'The Galway Hat Shop',
#     'location': {'address': 'Corbett Court, Eyre Square Shopping Centre',
#      'lat': 53.2742856685292,
#      'lng': -9.050674438476562,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.2742856685292,
#        'lng': -9.050674438476562}],
#      'distance': 108,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Corbett Court, Eyre Square Shopping Centre',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '57907ebe498ee6901d1918d9',
#     'name': 'Concrete Jungle',
#     'location': {'lat': 53.274254,
#      'lng': -9.049118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274254,
#        'lng': -9.049118}],
#      'distance': 17,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4da2bbb222a5f04d72eb1555',
#     'name': 'Lavazza',
#     'location': {'lat': 53.27461423734278,
#      'lng': -9.050315461973062,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27461423734278,
#        'lng': -9.050315461973062}],
#      'distance': 86,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5156f583e4b0210cd0ac52b8',
#     'name': 'Lucaffe',
#     'location': {'lat': 53.273695,
#      'lng': -9.049571,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.273695,
#        'lng': -9.049571}],
#      'distance': 86,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '54664d09498e4869daa49ea8',
#     'name': 'mulholland bookmaker',
#     'location': {'lat': 53.2751,
#      'lng': -9.049341,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.2751,
#        'lng': -9.049341}],
#      'distance': 78,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b40',
#       'name': 'Betting Shop',
#       'pluralName': 'Betting Shops',
#       'shortName': 'Betting Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5385b4d0498e7995144f6964',
#     'name': 'Naomh Padraig Credit Union',
#     'location': {'address': 'Eyre Square',
#      'lat': 53.274078369140625,
#      'lng': -9.04970645904541,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274078369140625,
#        'lng': -9.04970645904541}],
#      'distance': 56,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Square', 'Ireland']},
#     'categories': [{'id': '5032850891d4c4b30a586d62',
#       'name': 'Credit Union',
#       'pluralName': 'Credit Unions',
#       'shortName': 'Credit Union',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4dff768dc65b10468962ddd9',
#     'name': 'O2',
#     'location': {'address': 'Williamsgate St',
#      'lat': 53.27423007472063,
#      'lng': -9.05080158146938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27423007472063,
#        'lng': -9.05080158146938}],
#      'distance': 117,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Williamsgate St',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#       'name': 'Mobile Phone Shop',
#       'pluralName': 'Mobile Phone Shops',
#       'shortName': 'Mobile Phones',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '505de423e4b04d802b46f7b0',
#     'name': 'Bus Stop 407',
#     'location': {'address': 'Eyre Square',
#      'lat': 53.27471536770069,
#      'lng': -9.047800653919465,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27471536770069,
#        'lng': -9.047800653919465}],
#      'distance': 90,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Square', 'Ireland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#       'name': 'Bus Stop',
#       'pluralName': 'Bus Stops',
#       'shortName': 'Bus Stop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4f12f61be4b07e9ecbf42025',
#     'name': 'Quincentennial Park',
#     'location': {'lat': 53.27383420051067,
#      'lng': -9.050166692406629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27383420051067,
#        'lng': -9.050166692406629}],
#      'distance': 97,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4ce7223594daa090c6d31b29',
#     'name': 'RedCats',
#     'location': {'address': 'Eyre Square Shopping Centre',
#      'lat': 53.27438613,
#      'lng': -9.05095977,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27438613,
#        'lng': -9.05095977}],
#      'distance': 126,
#      'postalCode': 'na',
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Eyre Square Shopping Centre',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '55cc4c09498e9cf3941e0606',
#     'name': 'g stop',
#     'location': {'lat': 53.27372922558751,
#      'lng': -9.050155812492047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27372922558751,
#        'lng': -9.050155812492047}],
#      'distance': 105,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '503229c4e4b04d70bfaecaae',
#     'name': 'Sun 4U Ray',
#     'location': {'address': 'Unit 8, Kiltartan House',
#      'crossStreet': 'Forster Street',
#      'lat': 53.274312343419616,
#      'lng': -9.047587708461093,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.274312343419616,
#        'lng': -9.047587708461093}],
#      'distance': 98,
#      'postalCode': 'Roi',
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Unit 8, Kiltartan House (Forster Street)',
#       'Galway',
#       'Co Galway',
#       'Ireland']},
#     'categories': [{'id': '4d1cf8421a97d635ce361c31',
#       'name': 'Tanning Salon',
#       'pluralName': 'Tanning Salons',
#       'shortName': 'Tanning Salon',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tanning_salon_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '5020d2b6e4b070b241e56c56',
#     'name': 'Heyrick Hot Tub',
#     'location': {'lat': 53.273878,
#      'lng': -9.048445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.273878,
#        'lng': -9.048445}],
#      'distance': 72,
#      'cc': 'IE',
#      'country': 'Ireland',
#      'formattedAddress': ['Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '53d8df56498e26f5393ae915',
#     'name': 'City Chiropractic',
#     'location': {'lat': 53.273768,
#      'lng': -9.04945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.273768,
#        'lng': -9.04945}],
#      'distance': 76,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3a',
#       'name': 'Chiropractor',
#       'pluralName': 'Chiropractors',
#       'shortName': 'Chiropractors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False},
#    {'id': '4f79d6fce4b05cde6310bfe8',
#     'name': 'McInerney Solicitors',
#     'location': {'address': '46 Eyre Squar',
#      'lat': 53.27483543171154,
#      'lng': -9.049565218246132,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 53.27483543171154,
#        'lng': -9.049565218246132}],
#      'distance': 57,
#      'cc': 'IE',
#      'city': 'Galway',
#      'state': 'Co Galway',
#      'country': 'Ireland',
#      'formattedAddress': ['46 Eyre Squar', 'Galway', 'Co Galway', 'Ireland']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1607711018',
#     'hasPerk': False}],
#   'confident': False}}

# %%
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d166941735', 'name': 'S...    False
# 1  [{'id': '4bf58dd8d48988d164941735', 'name': 'P...    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d155941735', 'name': 'G...    False
#
#                          id    location.address location.cc location.city  \
# 0  522322d0498ee3e39d979b57             Eyre Sq          IE        Galway
# 1  4b6ef741f964a520a9d32ce3     An Fhaiche Mhór          IE        Galway
# 2  56178f87498e3bd23df18f8c      11 Eyre Square          IE        Galway
# 3  4b641d83f964a520c49f2ae3             Eyre Sq          IE        Galway
# 4  558a8a96498e2fb39e16521f  9-11 Prospect Hill          IE        Galway
#
#   location.country location.crossStreet  location.distance  \
# 0          Ireland                  NaN                 59
# 1          Ireland                  NaN                 11
# 2          Ireland                  NaN                 68
# 3          Ireland                  NaN                 52
# 4          Ireland                  NaN                107
#
#                           location.formattedAddress  \
# 0             [Eyre Sq, Galway, Co Galway, Ireland]
# 1     [An Fhaiche Mhór, Galway, Co Galway, Ireland]
# 2      [11 Eyre Square, Galway, Co Galway, Ireland]
# 3             [Eyre Sq, Galway, Co Galway, Ireland]
# 4  [9-11 Prospect Hill, Galway, Co Galway, Ireland]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 53.27477630954029...     53.274776
# 1  [{'label': 'display', 'lat': 53.27449738551782...     53.274497
# 2  [{'label': 'display', 'lat': 53.274371, 'lng':...     53.274371
# 3  [{'label': 'display', 'lat': 53.27418765157748...     53.274188
# 4  [{'label': 'display', 'lat': 53.27537801076868...     53.275378
#
#    location.lng location.neighborhood location.postalCode location.state  \
# 0     -9.049726                   NaN                 NaN      Co Galway
# 1     -9.049172                   NaN                 NaN      Co Galway
# 2     -9.048041           Eyre Square                 NaN      Co Galway
# 3     -9.048374                   NaN                 NaN      Co Galway
# 4     -9.048960                   NaN                 NaN      Co Galway
#
#                  name    referralId
# 0  The Browne Doorway  v-1607711018
# 1         Eyre Square  v-1607711018
# 2     Esquires Coffee  v-1607711018
# 3       Meyrick Hotel  v-1607711018
# 4        McGettigan's  v-1607711018

# %%
dataframe.shape
# Out:
# (125, 18)

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                            name                   categories  \
# 0            The Browne Doorway             Sculpture Garden
# 1                   Eyre Square                        Plaza
# 2               Esquires Coffee                  Coffee Shop
# 3                 Meyrick Hotel                        Hotel
# 4                  McGettigan's                    Gastropub
# 5        Skeffington Arms Hotel                        Hotel
# 6        Corrib Shopping Centre                Shopping Mall
# 7                 Lynchs Castle                       Castle
# 8                     The Skeff                    Hotel Bar
# 9                       An Post                  Post Office
# 10               The Dough Bros                  Pizza Place
# 11                AXA Insurance             Insurance Office
# 12                    Starbucks                  Coffee Shop
# 13                  O'Connell's                          Pub
# 14                 Café Express           Italian Restaurant
# 15            Burkes Bus Galway                  Bus Station
# 16                        Dealz               Discount Store
# 17                   Paddys Bar                          Pub
# 18     Free Walking Tour Galway                Tour Provider
# 19                        Remax           Real Estate Office
# 20      John F Kennedy Monument          Monument / Landmark
# 21                        Shake                 Dessert Shop
# 22                   Caffè Nero                  Coffee Shop
# 23                 Gala Express                Grocery Store
# 24              Lazlo Jewellers                Jewelry Store
# 25        Liam Maoiliosa Statue          Monument / Landmark
# 26                          DNA                    Nightclub
# 27      Tropical Medical Bureau               Medical Center
# 28            Eyre Square Hotel                        Hotel
# 29       Ciarán's Accommodation              Bed & Breakfast
# ..                          ...                          ...
# 95              51X to Limerick                     Bus Line
# 96     Galway Bike Station 4022     Bike Rental / Bike Share
# 97              the coffee shop                         Café
# 98                 Boyle Sports           Athletics & Sports
# 99            Whelan's Pharmacy                     Pharmacy
# 100                     Netcafe  Professional & Other Places
# 101                    Vodafone            Mobile Phone Shop
# 102                Jack & Jones                  Men's Store
# 103                Leisure Club                        Hotel
# 104      Regatta Great Outdoors               Clothing Store
# 105                         Cex             Video Game Store
# 106                      Club Q                    Nightclub
# 107                    Kilronan                         None
# 108   Citylink Dublin to Galway                     Bus Line
# 109              LloydsPharmacy                     Pharmacy
# 110         The Galway Hat Shop           Miscellaneous Shop
# 111             Concrete Jungle                  Coffee Shop
# 112                     Lavazza                  Coffee Shop
# 113                     Lucaffe                  Coffee Shop
# 114        mulholland bookmaker                 Betting Shop
# 115  Naomh Padraig Credit Union                 Credit Union
# 116                          O2            Mobile Phone Shop
# 117                Bus Stop 407                     Bus Stop
# 118         Quincentennial Park                         Park
# 119                     RedCats           Salon / Barbershop
# 120                      g stop                         Café
# 121                  Sun 4U Ray                Tanning Salon
# 122             Heyrick Hot Tub                     Building
# 123           City Chiropractic                 Chiropractor
# 124        McInerney Solicitors                       Office
#
#                                         address  cc    city  country  \
# 0                                       Eyre Sq  IE  Galway  Ireland
# 1                               An Fhaiche Mhór  IE  Galway  Ireland
# 2                                11 Eyre Square  IE  Galway  Ireland
# 3                                       Eyre Sq  IE  Galway  Ireland
# 4                            9-11 Prospect Hill  IE  Galway  Ireland
# 5                                       Eyre Sq  IE  Galway  Ireland
# 6                                       Eyre St  IE  Galway  Ireland
# 7                                           NaN  IE  Galway  Ireland
# 8                                       Eyre Sq  IE  Galway  Ireland
# 9                                           NaN  IE  Galway  Ireland
# 10                                    Middle St  IE  Galway  Ireland
# 11                               Woodquay Court  IE  Galway  Ireland
# 12                  Eyre Square Shopping Centre  IE  Galway  Ireland
# 13                                    8 Eyre Sq  IE  Galway  Ireland
# 14                                   32 Eyre Sq  IE  Galway  Ireland
# 15                                          NaN  IE  Galway  Ireland
# 16                 Hibernian House, Eyre Square  IE  Galway  Ireland
# 17                                          NaN  IE  Galway  Ireland
# 18                                          NaN  IE  Galway  Ireland
# 19                                          NaN  IE  Galway  Ireland
# 20                                          NaN  IE  Galway  Ireland
# 21                Corbett Court Shopping Centre  IE  Galway  Ireland
# 22                                  Eyre Square  IE  Galway  Ireland
# 23                              6 Prospect Hill  IE  Galway  Ireland
# 24                                20 William St  IE  Galway  Ireland
# 25                                          NaN  IE  Galway  Ireland
# 26                                          NaN  IE  Galway  Ireland
# 27                                          NaN  IE     NaN  Ireland
# 28                                   Forster St  IE  Galway  Ireland
# 29                             50 Prospect Hill  IE  Galway  Ireland
# ..                                          ...  ..     ...      ...
# 95                                  Bus Éireann  IE  Galway  Ireland
# 96                                          NaN  IE  Galway  Ireland
# 97                                          NaN  IE     NaN  Ireland
# 98                                          NaN  IE  Galway  Ireland
# 99                          Williamsgate Street  IE  Galway  Ireland
# 100                                         NaN  IE  Galway  Ireland
# 101                                         NaN  IE  Galway  Ireland
# 102                          Eyre Square Centre  IE  Galway  Ireland
# 103                      Meyrick Hotel, Eyre Sq  IE  Galway  Ireland
# 104                                         NaN  IE  Galway  Ireland
# 105                                         NaN  IE     NaN  Ireland
# 106                              Radisson Hotel  IE  Galway  Ireland
# 107                                    Inis Mor  IE     NaN  Ireland
# 108                                         NaN  IE     NaN  Ireland
# 109                                         NaN  IE     NaN  Ireland
# 110  Corbett Court, Eyre Square Shopping Centre  IE  Galway  Ireland
# 111                                         NaN  IE  Galway  Ireland
# 112                                         NaN  IE  Galway  Ireland
# 113                                         NaN  IE  Galway  Ireland
# 114                                         NaN  IE  Galway  Ireland
# 115                                 Eyre Square  IE     NaN  Ireland
# 116                             Williamsgate St  IE  Galway  Ireland
# 117                                 Eyre Square  IE     NaN  Ireland
# 118                                         NaN  IE  Galway  Ireland
# 119                 Eyre Square Shopping Centre  IE  Galway  Ireland
# 120                                         NaN  IE     NaN  Ireland
# 121                     Unit 8, Kiltartan House  IE  Galway  Ireland
# 122                                         NaN  IE     NaN  Ireland
# 123                                         NaN  IE  Galway  Ireland
# 124                               46 Eyre Squar  IE  Galway  Ireland
#
#          crossStreet  distance  \
# 0                NaN        59
# 1                NaN        11
# 2                NaN        68
# 3                NaN        52
# 4                NaN       107
# 5                NaN        46
# 6                NaN       144
# 7                NaN       236
# 8                NaN        69
# 9                NaN        13
# 10               NaN       260
# 11               NaN        13
# 12               NaN        89
# 13               NaN        32
# 14               NaN        93
# 15               NaN        49
# 16           Eyre Sq       117
# 17               NaN       187
# 18               NaN        58
# 19               NaN        47
# 20               NaN        39
# 21               NaN       103
# 22               NaN        49
# 23               NaN        82
# 24       Galway City        37
# 25               NaN        76
# 26               NaN       110
# 27               NaN        60
# 28               NaN       109
# 29               NaN         8
# ..               ...       ...
# 95   An Fhaiche Mhór       120
# 96               NaN        77
# 97               NaN       124
# 98               NaN       106
# 99   Eglinton Street        98
# 100              NaN        90
# 101              NaN        66
# 102              NaN        97
# 103              NaN        77
# 104              NaN        88
# 105              NaN       124
# 106              NaN       102
# 107              NaN         4
# 108              NaN        81
# 109              NaN       122
# 110              NaN       108
# 111              NaN        17
# 112              NaN        86
# 113              NaN        86
# 114              NaN        78
# 115              NaN        56
# 116              NaN       117
# 117              NaN        90
# 118              NaN        97
# 119              NaN       126
# 120              NaN       105
# 121   Forster Street        98
# 122              NaN        72
# 123              NaN        76
# 124              NaN        57
#
#                                       formattedAddress  \
# 0                [Eyre Sq, Galway, Co Galway, Ireland]
# 1        [An Fhaiche Mhór, Galway, Co Galway, Ireland]
# 2         [11 Eyre Square, Galway, Co Galway, Ireland]
# 3                [Eyre Sq, Galway, Co Galway, Ireland]
# 4     [9-11 Prospect Hill, Galway, Co Galway, Ireland]
# 5                [Eyre Sq, Galway, Co Galway, Ireland]
# 6                [Eyre St, Galway, Co Galway, Ireland]
# 7                         [Galway, Co Galway, Ireland]
# 8                [Eyre Sq, Galway, Co Galway, Ireland]
# 9                         [Galway, Co Galway, Ireland]
# 10             [Middle St, Galway, Co Galway, Ireland]
# 11        [Woodquay Court, Galway, Co Galway, Ireland]
# 12   [Eyre Square Shopping Centre, Galway, Co Galwa...
# 13             [8 Eyre Sq, Galway, Co Galway, Ireland]
# 14            [32 Eyre Sq, Galway, Co Galway, Ireland]
# 15                        [Galway, Co Galway, Ireland]
# 16   [Hibernian House, Eyre Square (Eyre Sq), Galwa...
# 17                        [Galway, Co Galway, Ireland]
# 18                        [Galway, Co Galway, Ireland]
# 19                        [Galway, Co Galway, Ireland]
# 20                        [Galway, Co Galway, Ireland]
# 21   [Corbett Court Shopping Centre, Galway, Co Gal...
# 22           [Eyre Square, Galway, Co Galway, Ireland]
# 23       [6 Prospect Hill, Galway, Co Galway, Ireland]
# 24   [20 William St (Galway City), Galway, Co Galwa...
# 25                        [Galway, Co Galway, Ireland]
# 26                        [Galway, Co Galway, Ireland]
# 27                                           [Ireland]
# 28            [Forster St, Galway, Co Galway, Ireland]
# 29      [50 Prospect Hill, Galway, Co Galway, Ireland]
# ..                                                 ...
# 95   [Bus Éireann (An Fhaiche Mhór), Galway, Co Gal...
# 96                        [Galway, Co Galway, Ireland]
# 97                                           [Ireland]
# 98                        [Galway, Co Galway, Ireland]
# 99   [Williamsgate Street (Eglinton Street), Galway...
# 100                       [Galway, Co Galway, Ireland]
# 101                       [Galway, Co Galway, Ireland]
# 102   [Eyre Square Centre, Galway, Co Galway, Ireland]
# 103  [Meyrick Hotel, Eyre Sq, Galway, Co Galway, Ir...
# 104                       [Galway, Co Galway, Ireland]
# 105                                          [Ireland]
# 106       [Radisson Hotel, Galway, Co Galway, Ireland]
# 107                                [Inis Mor, Ireland]
# 108                                          [Ireland]
# 109                                          [Ireland]
# 110  [Corbett Court, Eyre Square Shopping Centre, G...
# 111                       [Galway, Co Galway, Ireland]
# 112                       [Galway, Co Galway, Ireland]
# 113                       [Galway, Co Galway, Ireland]
# 114                       [Galway, Co Galway, Ireland]
# 115                             [Eyre Square, Ireland]
# 116      [Williamsgate St, Galway, Co Galway, Ireland]
# 117                             [Eyre Square, Ireland]
# 118                       [Galway, Co Galway, Ireland]
# 119  [Eyre Square Shopping Centre, Galway, Co Galwa...
# 120                                          [Ireland]
# 121  [Unit 8, Kiltartan House (Forster Street), Gal...
# 122                                          [Ireland]
# 123                       [Galway, Co Galway, Ireland]
# 124        [46 Eyre Squar, Galway, Co Galway, Ireland]
#
#                                         labeledLatLngs        lat       lng  \
# 0    [{'label': 'display', 'lat': 53.27477630954029...  53.274776 -9.049726
# 1    [{'label': 'display', 'lat': 53.27449738551782...  53.274497 -9.049172
# 2    [{'label': 'display', 'lat': 53.274371, 'lng':...  53.274371 -9.048041
# 3    [{'label': 'display', 'lat': 53.27418765157748...  53.274188 -9.048374
# 4    [{'label': 'display', 'lat': 53.27537801076868...  53.275378 -9.048960
# 5    [{'label': 'display', 'lat': 53.27422769415862...  53.274228 -9.049688
# 6    [{'label': 'display', 'lat': 53.27542777992054...  53.275428 -9.050417
# 7    [{'label': 'display', 'lat': 53.27329, 'lng': ...  53.273290 -9.052086
# 8    [{'label': 'display', 'lat': 53.274120143583, ...  53.274120 -9.049978
# 9    [{'label': 'display', 'lat': 53.27442581304661...  53.274426 -9.048861
# 10   [{'label': 'display', 'lat': 53.27268249426422...  53.272682 -9.051698
# 11   [{'label': 'display', 'lat': 53.27434982530317...  53.274350 -9.048893
# 12   [{'label': 'display', 'lat': 53.27363112900194...  53.273631 -9.049350
# 13   [{'label': 'display', 'lat': 53.27449014278099...  53.274490 -9.048592
# 14   [{'label': 'display', 'lat': 53.27446530725363...  53.274465 -9.050471
# 15   [{'label': 'display', 'lat': 53.274375, 'lng':...  53.274375 -9.048323
# 16   [{'label': 'display', 'lat': 53.2753283, 'lng'...  53.275328 -9.049940
# 17   [{'label': 'display', 'lat': 53.27608463280089...  53.276085 -9.048689
# 18   [{'label': 'display', 'lat': 53.27422, 'lng': ...  53.274220 -9.049879
# 19   [{'label': 'display', 'lat': 53.274632, 'lng':...  53.274632 -9.048458
# 20   [{'label': 'display', 'lat': 53.274512, 'lng':...  53.274512 -9.048498
# 21   [{'label': 'display', 'lat': 53.27435503032173...  53.274355 -9.050609
# 22   [{'label': 'display', 'lat': 53.27437217373234...  53.274372 -9.049804
# 23   [{'label': 'display', 'lat': 53.275149, 'lng':...  53.275149 -9.049146
# 24   [{'label': 'display', 'lat': 53.274742, 'lng':...  53.274742 -9.048938
# 25   [{'label': 'display', 'lat': 53.275094, 'lng':...  53.275094 -9.049232
# 26   [{'label': 'display', 'lat': 53.273721, 'lng':...  53.273721 -9.050246
# 27   [{'label': 'display', 'lat': 53.27492523193359...  53.274925 -9.048766
# 28   [{'label': 'display', 'lat': 53.27430143339912...  53.274301 -9.047428
# 29   [{'label': 'display', 'lat': 53.274426, 'lng':...  53.274426 -9.048941
# ..                                                 ...        ...       ...
# 95   [{'label': 'display', 'lat': 53.27390754380205...  53.273908 -9.047468
# 96   [{'label': 'display', 'lat': 53.274208, 'lng':...  53.274208 -9.047951
# 97   [{'label': 'display', 'lat': 53.27426147460937...  53.274261 -9.050914
# 98   [{'label': 'display', 'lat': 53.27536548921077...  53.275365 -9.049087
# 99   [{'label': 'display', 'lat': 53.27410474439536...  53.274105 -9.050454
# 100  [{'label': 'display', 'lat': 53.27451441496048...  53.274514 -9.047711
# 101  [{'label': 'display', 'lat': 53.27447870793053...  53.274479 -9.050052
# 102  [{'label': 'display', 'lat': 53.27502733091735...  53.275027 -9.050110
# 103  [{'label': 'display', 'lat': 53.274198, 'lng':...  53.274198 -9.047963
# 104  [{'label': 'display', 'lat': 53.273631, 'lng':...  53.273631 -9.049347
# 105  [{'label': 'display', 'lat': 53.274365, 'lng':...  53.274365 -9.047197
# 106  [{'label': 'display', 'lat': 53.27436412649219...  53.274364 -9.050594
# 107  [{'label': 'display', 'lat': 53.27441668129248...  53.274417 -9.049002
# 108  [{'label': 'display', 'lat': 53.27400664575430...  53.274007 -9.048047
# 109  [{'label': 'display', 'lat': 53.27457, 'lng': ...  53.274570 -9.047245
# 110  [{'label': 'display', 'lat': 53.2742856685292,...  53.274286 -9.050674
# 111  [{'label': 'display', 'lat': 53.274254, 'lng':...  53.274254 -9.049118
# 112  [{'label': 'display', 'lat': 53.27461423734278...  53.274614 -9.050315
# 113  [{'label': 'display', 'lat': 53.273695, 'lng':...  53.273695 -9.049571
# 114  [{'label': 'display', 'lat': 53.2751, 'lng': -...  53.275100 -9.049341
# 115  [{'label': 'display', 'lat': 53.27407836914062...  53.274078 -9.049706
# 116  [{'label': 'display', 'lat': 53.27423007472063...  53.274230 -9.050802
# 117  [{'label': 'display', 'lat': 53.27471536770069...  53.274715 -9.047801
# 118  [{'label': 'display', 'lat': 53.27383420051067...  53.273834 -9.050167
# 119  [{'label': 'display', 'lat': 53.27438613, 'lng...  53.274386 -9.050960
# 120  [{'label': 'display', 'lat': 53.27372922558751...  53.273729 -9.050156
# 121  [{'label': 'display', 'lat': 53.27431234341961...  53.274312 -9.047588
# 122  [{'label': 'display', 'lat': 53.273878, 'lng':...  53.273878 -9.048445
# 123  [{'label': 'display', 'lat': 53.273768, 'lng':...  53.273768 -9.049450
# 124  [{'label': 'display', 'lat': 53.27483543171154...  53.274835 -9.049565
#
#      neighborhood postalCode      state                        id
# 0             NaN        NaN  Co Galway  522322d0498ee3e39d979b57
# 1             NaN        NaN  Co Galway  4b6ef741f964a520a9d32ce3
# 2     Eyre Square        NaN  Co Galway  56178f87498e3bd23df18f8c
# 3             NaN        NaN  Co Galway  4b641d83f964a520c49f2ae3
# 4             NaN        NaN  Co Galway  558a8a96498e2fb39e16521f
# 5             NaN        NaN  Co Galway  4be1aeb88dd062b5597b3e3c
# 6             NaN        NaN  Co Galway  4be54bfc2468c92821daff42
# 7    St. Nicholas        NaN  Co Galway  5b686bf7e96d0c002ca3d69e
# 8             NaN        NaN  Co Galway  4b983585f964a520603435e3
# 9             NaN        NaN  Co Galway  4bd590b95631c9b6503da430
# 10            NaN        NaN  Co Galway  53495199498e14b6d3ab10b5
# 11            NaN   H91 XW5A  Co Galway  58c7f6b77b88a73f653685c2
# 12            NaN        NaN  Co Galway  590dd9a728374e10e4241aee
# 13            NaN        NaN  Co Galway  4b086877f964a520340b23e3
# 14            NaN        NaN  Co Galway  4dc97374e4cd1818d5b89db3
# 15            NaN        NaN  Co Galway  5b03061d780eee002cebfbd1
# 16            NaN        NaN  Co Galway  5706b844498e54311369e776
# 17            NaN        NaN  Co Galway  4dd7a53fe4cd37c893b0090f
# 18            NaN        NaN  Co Galway  5d78f103863de600077321ac
# 19            NaN        NaN  Co Galway  5e42c8f5b8c0660008ac7fea
# 20            NaN        NaN  Co Galway  5d57e019284dc20008b905af
# 21            NaN        NaN  Co Galway  4c5841a52308be9accf55a6c
# 22            NaN        NaN  Co Galway  598c315fc0cacb28d86a6f7b
# 23            NaN        NaN  Co Galway  4c5038f3371520a1adf1f2c0
# 24            NaN   H91 F8D9  Co Galway  4e4bd38722713bd908c2ea76
# 25            NaN        NaN  Co Galway  5d5d7852a20381000786d723
# 26            NaN        NaN  Co Galway  598652adbd400967fb7a0611
# 27            NaN        NaN        NaN  52012547498e621d68695acc
# 28            NaN        NaN  Co Galway  4baeccfaf964a52027d93be3
# 29            NaN        NaN  Co Galway  4e22c8cdd4c0d32590fc3b68
# ..            ...        ...        ...                       ...
# 95            NaN        NaN  Co Galway  545de9c4498e4d476e5fc508
# 96            NaN        NaN  Co Galway  5b3b1de366f3cd002bf3ff57
# 97            NaN        NaN        NaN  4f40e1bce4b0295029833b1a
# 98            NaN        NaN  Co Galway  570929ef498e04ec2bcce5de
# 99            NaN        NaN  Co Galway  4d777eb17484b60c79103dd9
# 100           NaN        NaN  Co Galway  4e3bee6cae604542364fe106
# 101           NaN        NaN  Co Galway  4e89d5d461afd3867c32638e
# 102           NaN        NaN  Co Galway  4f0b049ce4b000dd78052cc1
# 103           NaN        NaN  Co Galway  59008d80c5b11c2a5526d652
# 104           NaN        NaN  Co Galway  5a0c56958194fc771289349b
# 105           NaN        NaN        NaN  580b789b38faa26bf0556236
# 106           NaN        NaN  Co Galway  4b64e332f964a52096d72ae3
# 107           NaN        NaN        NaN  4deb8fbcd22da22d4ef04898
# 108           NaN        NaN        NaN  5357f54b498e123098972ef9
# 109           NaN        NaN        NaN  578e55b4498e4401d720edfd
# 110           NaN        NaN  Co Galway  4e1425df1fc78d2d5d124990
# 111           NaN        NaN  Co Galway  57907ebe498ee6901d1918d9
# 112           NaN        NaN  Co Galway  4da2bbb222a5f04d72eb1555
# 113           NaN        NaN  Co Galway  5156f583e4b0210cd0ac52b8
# 114           NaN        NaN  Co Galway  54664d09498e4869daa49ea8
# 115           NaN        NaN        NaN  5385b4d0498e7995144f6964
# 116           NaN        NaN  Co Galway  4dff768dc65b10468962ddd9
# 117           NaN        NaN        NaN  505de423e4b04d802b46f7b0
# 118           NaN        NaN  Co Galway  4f12f61be4b07e9ecbf42025
# 119           NaN         na  Co Galway  4ce7223594daa090c6d31b29
# 120           NaN        NaN        NaN  55cc4c09498e9cf3941e0606
# 121           NaN        Roi  Co Galway  503229c4e4b04d70bfaecaae
# 122           NaN        NaN        NaN  5020d2b6e4b070b241e56c56
# 123           NaN        NaN  Co Galway  53d8df56498e26f5393ae915
# 124           NaN        NaN  Co Galway  4f79d6fce4b05cde6310bfe8
#
# [125 rows x 16 columns]

# %%
dataframe_filtered.name.head()
# Out:
# 0    The Browne Doorway
# 1           Eyre Square
# 2       Esquires Coffee
# 3         Meyrick Hotel
# 4          McGettigan's
# Name: name, dtype: object

# %%
galway_venues_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

#markdown all venues:

for lat, lng, categories in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    label = categories
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = 'grey',
        fill_opacity = .6,
        parse_html = False).add_to(galway_venues_map)
galway_venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered.rename(columns={'address' : 'Address', 'lat' : 'Latitude', 'lng':'Longitude'}, inplace = True)
dataframe_filtered.head()
# Out:
#                  name        categories             Address  cc    city  \
# 0  The Browne Doorway  Sculpture Garden             Eyre Sq  IE  Galway
# 1         Eyre Square             Plaza     An Fhaiche Mhór  IE  Galway
# 2     Esquires Coffee       Coffee Shop      11 Eyre Square  IE  Galway
# 3       Meyrick Hotel             Hotel             Eyre Sq  IE  Galway
# 4        McGettigan's         Gastropub  9-11 Prospect Hill  IE  Galway
#
#    country crossStreet  distance  \
# 0  Ireland         NaN        59
# 1  Ireland         NaN        11
# 2  Ireland         NaN        68
# 3  Ireland         NaN        52
# 4  Ireland         NaN       107
#
#                                    formattedAddress  \
# 0             [Eyre Sq, Galway, Co Galway, Ireland]
# 1     [An Fhaiche Mhór, Galway, Co Galway, Ireland]
# 2      [11 Eyre Square, Galway, Co Galway, Ireland]
# 3             [Eyre Sq, Galway, Co Galway, Ireland]
# 4  [9-11 Prospect Hill, Galway, Co Galway, Ireland]
#
#                                       labeledLatLngs   Latitude  Longitude  \
# 0  [{'label': 'display', 'lat': 53.27477630954029...  53.274776  -9.049726
# 1  [{'label': 'display', 'lat': 53.27449738551782...  53.274497  -9.049172
# 2  [{'label': 'display', 'lat': 53.274371, 'lng':...  53.274371  -9.048041
# 3  [{'label': 'display', 'lat': 53.27418765157748...  53.274188  -9.048374
# 4  [{'label': 'display', 'lat': 53.27537801076868...  53.275378  -9.048960
#
#   neighborhood postalCode      state                        id
# 0          NaN        NaN  Co Galway  522322d0498ee3e39d979b57
# 1          NaN        NaN  Co Galway  4b6ef741f964a520a9d32ce3
# 2  Eyre Square        NaN  Co Galway  56178f87498e3bd23df18f8c
# 3          NaN        NaN  Co Galway  4b641d83f964a520c49f2ae3
# 4          NaN        NaN  Co Galway  558a8a96498e2fb39e16521f

# %%
#merging data from different dataframes based on Address values 
new_df = pd.merge(df, dataframe_filtered, how = 'left', on = 'Address')
new_df.head()
# Out:
#        Building_Name                          Address         County  \
# 0   Thatched Cottage   Ballycleary Kinvara Co. Galway  County Galway
# 1  Windfield House.   Newbridge Ballinasloe Co Galway  County Galway
# 2        Cregg Mills               Corrandulla GALWAY  County Galway
# 3      O'Dea's Hotel     Bride Street Loughrea Galway  County Galway
# 4         L O' Brien      Main Street Loughrea Galway  County Galway
#
#         Building_Type                                        Description  \
# 0  Thatched structure   Detached 4 bay , single storey thatched cottage.
# 1               House  Detached 3 bay, single storey over basement ho...
# 2          Mill house  DECLARATION Five-bay four-storey mill building...
# 3               Hotel  DECLARATION 11/6/2014  Late 18th century 7 bay...
# 4               House      Large 5 bay 3 storey late 18th century  house
#
#                                            Appraisal Current_Use  \
# 0      traditional roof,and  traditional setting.       dwelling
# 1  House which retains original features in inter...         NaN
# 2  DECLARATION Although devoid of machinery the b...    dwelling
# 3  DECLARATION 11/6/2014  The building is of regi...       hotel
# 4                                                NaN         NaN
#
#           Date_Registered  Latitude_x  Longitude_x  ...  crossStreet distance  \
# 0  1970/01/01 00:00:00+00   53.154390     -8.91107  ...          NaN      NaN
# 1  1970/01/01 00:00:00+00   53.505061     -8.46177  ...          NaN      NaN
# 2  2002/11/18 00:00:00+00   53.386900     -8.97269  ...          NaN      NaN
# 3  2005/10/25 00:00:00+00   53.199130     -8.56517  ...          NaN      NaN
# 4  2005/10/26 00:00:00+00   53.198660     -8.56860  ...          NaN      NaN
#
#   formattedAddress labeledLatLngs Latitude_y Longitude_y neighborhood  \
# 0              NaN            NaN        NaN         NaN          NaN
# 1              NaN            NaN        NaN         NaN          NaN
# 2              NaN            NaN        NaN         NaN          NaN
# 3              NaN            NaN        NaN         NaN          NaN
# 4              NaN            NaN        NaN         NaN          NaN
#
#    postalCode state   id
# 0         NaN   NaN  NaN
# 1         NaN   NaN  NaN
# 2         NaN   NaN  NaN
# 3         NaN   NaN  NaN
# 4         NaN   NaN  NaN
#
# [5 rows x 26 columns]

# %%
#merging data from different dataframes based on Geocordinates 
new_df = pd.merge(df, dataframe_filtered, how = 'left', on = ['Latitude', 'Longitude'])
new_df.head()
# Out:
#        Building_Name                        Address_x         County  \
# 0   Thatched Cottage   Ballycleary Kinvara Co. Galway  County Galway
# 1  Windfield House.   Newbridge Ballinasloe Co Galway  County Galway
# 2        Cregg Mills               Corrandulla GALWAY  County Galway
# 3      O'Dea's Hotel     Bride Street Loughrea Galway  County Galway
# 4         L O' Brien      Main Street Loughrea Galway  County Galway
#
#         Building_Type                                        Description  \
# 0  Thatched structure   Detached 4 bay , single storey thatched cottage.
# 1               House  Detached 3 bay, single storey over basement ho...
# 2          Mill house  DECLARATION Five-bay four-storey mill building...
# 3               Hotel  DECLARATION 11/6/2014  Late 18th century 7 bay...
# 4               House      Large 5 bay 3 storey late 18th century  house
#
#                                            Appraisal Current_Use  \
# 0      traditional roof,and  traditional setting.       dwelling
# 1  House which retains original features in inter...         NaN
# 2  DECLARATION Although devoid of machinery the b...    dwelling
# 3  DECLARATION 11/6/2014  The building is of regi...       hotel
# 4                                                NaN         NaN
#
#           Date_Registered   Latitude  Longitude  ...  city country  \
# 0  1970/01/01 00:00:00+00  53.154390   -8.91107  ...   NaN     NaN
# 1  1970/01/01 00:00:00+00  53.505061   -8.46177  ...   NaN     NaN
# 2  2002/11/18 00:00:00+00  53.386900   -8.97269  ...   NaN     NaN
# 3  2005/10/25 00:00:00+00  53.199130   -8.56517  ...   NaN     NaN
# 4  2005/10/26 00:00:00+00  53.198660   -8.56860  ...   NaN     NaN
#
#   crossStreet distance formattedAddress labeledLatLngs neighborhood  \
# 0         NaN      NaN              NaN            NaN          NaN
# 1         NaN      NaN              NaN            NaN          NaN
# 2         NaN      NaN              NaN            NaN          NaN
# 3         NaN      NaN              NaN            NaN          NaN
# 4         NaN      NaN              NaN            NaN          NaN
#
#   postalCode  state   id
# 0        NaN    NaN  NaN
# 1        NaN    NaN  NaN
# 2        NaN    NaN  NaN
# 3        NaN    NaN  NaN
# 4        NaN    NaN  NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# Whether address or geocordinates have been used for merging datasets we came up with the same five location common for both datasets. Let's make slightly different order of datasets before merging based on geocordinates.

# %%
 new_df = pd.merge(dataframe_filtered, df, how = 'left', on = ['Latitude', 'Longitude'])
new_df.head()
# Out:
#                  name        categories           Address_x  cc    city  \
# 0  The Browne Doorway  Sculpture Garden             Eyre Sq  IE  Galway
# 1         Eyre Square             Plaza     An Fhaiche Mhór  IE  Galway
# 2     Esquires Coffee       Coffee Shop      11 Eyre Square  IE  Galway
# 3       Meyrick Hotel             Hotel             Eyre Sq  IE  Galway
# 4        McGettigan's         Gastropub  9-11 Prospect Hill  IE  Galway
#
#    country crossStreet  distance  \
# 0  Ireland         NaN        59
# 1  Ireland         NaN        11
# 2  Ireland         NaN        68
# 3  Ireland         NaN        52
# 4  Ireland         NaN       107
#
#                                    formattedAddress  \
# 0             [Eyre Sq, Galway, Co Galway, Ireland]
# 1     [An Fhaiche Mhór, Galway, Co Galway, Ireland]
# 2      [11 Eyre Square, Galway, Co Galway, Ireland]
# 3             [Eyre Sq, Galway, Co Galway, Ireland]
# 4  [9-11 Prospect Hill, Galway, Co Galway, Ireland]
#
#                                       labeledLatLngs  ...  \
# 0  [{'label': 'display', 'lat': 53.27477630954029...  ...
# 1  [{'label': 'display', 'lat': 53.27449738551782...  ...
# 2  [{'label': 'display', 'lat': 53.274371, 'lng':...  ...
# 3  [{'label': 'display', 'lat': 53.27418765157748...  ...
# 4  [{'label': 'display', 'lat': 53.27537801076868...  ...
#
#                          id  Building_Name Address_y County Building_Type  \
# 0  522322d0498ee3e39d979b57            NaN       NaN    NaN           NaN
# 1  4b6ef741f964a520a9d32ce3            NaN       NaN    NaN           NaN
# 2  56178f87498e3bd23df18f8c            NaN       NaN    NaN           NaN
# 3  4b641d83f964a520c49f2ae3            NaN       NaN    NaN           NaN
# 4  558a8a96498e2fb39e16521f            NaN       NaN    NaN           NaN
#
#   Description Appraisal Current_Use Date_Registered OBJECTID
# 0         NaN       NaN         NaN             NaN      NaN
# 1         NaN       NaN         NaN             NaN      NaN
# 2         NaN       NaN         NaN             NaN      NaN
# 3         NaN       NaN         NaN             NaN      NaN
# 4         NaN       NaN         NaN             NaN      NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Results and Disscusion

# %% [markdown]
# After comparation has been made between two dataframes we finally have some numbers and they goes like this:
#
# - 1514 Registrated protected structures according to dataset,
# - 119 Registrated protected structures currently in use,
# - 5 only amoung them are enlisted in Foursquare.
#
# Only 7.86% from those recorded are currently in use. And only 0.33% from all recorded structures are worldwide visible throughout the Foursquare platform.
#
# Although the number of currently used structures could be a higher than in dataset. The base for this assumption is grounded in results obtaind by merging two datasets based on geocordinates. Windfield House and L O'Brien House under the Current_Use column have NaN value for which I have made assumption that it means that these datapoints represent currently non used structures. Yet these Houses have appeared on Foursquare platform in category for Hotels.
#
# Newertheless it's fairly small number if we take into the account complete list of Recorded structures, and as it could have been seen the list is quiet impressive.
#
# Reason for so small number of Protected Structures in some way included in tourism of Galway County can be numerus. And they ceartainly must be investigated in order to improve tourist offer of County.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Although results have shown that fairly small number of structures enlisted as protected by Galway County Council, that as such possess certain historical, cultural, architectural value, are presented as Tourist attracion.
#
# Lot's of at first sight, interesting buildings are not. Their inclusion in tourist offer of County can be benefitial from many aspects and one of main is Economic aspect for County, as well as budget for their preservation also educational character they can have for all that decide to see them.
# Those enlisted but not offered to a broader publicity represent potential that must be examined and included in Tourist prospects of County.
# With broader offer cames more people who in that case usually love to stay a day or two more, who need to eat and if it's a local food than there is more job for local restorans as well as farmers. And this is not where chain is closed because  these people live traces - comments and pictures about places they have visited and draw another to follow them.

# %% [markdown]
# Copyright zmajstorovic111@gmail.com, 2020.
